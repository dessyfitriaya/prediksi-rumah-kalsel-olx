# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from sklearn.model_selection import train_test_split, RandomizedSearchCV, validation_curve
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
df = pd.read_csv("bismillah.csv")

# %% [markdown]
# ## One-Hot Encoder

# %%
from sklearn.preprocessing import OneHotEncoder

df = pd.concat([df, pd.get_dummies(df['kota'], prefix='kota')], axis=1)
df = pd.concat([df, pd.get_dummies(df['kecamatan'], prefix='kecamatan')], axis=1)
df.drop(['kota', 'kecamatan'], axis=1, inplace=True)
df.head()
# Out:
#    kamar_tidur  kamar_mandi  luas      harga  kota_Banjar  kota_Banjarbaru  \
# 0            2            2    70  400000000        False            False
# 1            2            1    60  400000000        False            False
# 2            2            1   120  550000000        False            False
# 3            3            2   100  555000000        False            False
# 4            2            1    45  400000000        False            False
#
#    kota_Banjarmasin  kota_Barito  kota_Kalimantan  kecamatan_Alalak  ...  \
# 0              True        False            False             False  ...
# 1              True        False            False             False  ...
# 2              True        False            False             False  ...
# 3              True        False            False             False  ...
# 4              True        False            False             False  ...
#
#    kecamatan_Banjarmasin Tengah  kecamatan_Banjarmasin Timur  \
# 0                         False                         True
# 1                         False                         True
# 2                         False                        False
# 3                         False                        False
# 4                         False                         True
#
#    kecamatan_Banjarmasin Utara  kecamatan_Gambut  kecamatan_Kertak Hanyar  \
# 0                        False             False                    False
# 1                        False             False                    False
# 2                         True             False                    False
# 3                         True             False                    False
# 4                        False             False                    False
#
#    kecamatan_Landasan Ulin  kecamatan_Liang Anggang  kecamatan_Martapura Kota  \
# 0                    False                    False                     False
# 1                    False                    False                     False
# 2                    False                    False                     False
# 3                    False                    False                     False
# 4                    False                    False                     False
#
#    kecamatan_Sei/Sungai Tabuk  kecamatan_Tatah Makmur
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Split Train Test

# %%
X = df.drop(columns=['harga'])
y = df['harga']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2, 
                                                    random_state = 137)

# %% [markdown]
# ## Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

numerical_features = ['kamar_mandi', 'kamar_tidur', 'luas']
scaler = StandardScaler()
scaler.fit(X_train[numerical_features])
X_train[numerical_features] = scaler.transform(X_train.loc[:, numerical_features])

# %% [markdown]
# ## Validation Curves

# %% [markdown]
# ### n_estimators

# %%
param_range = list(range(0, 100))

train_scores, test_scores = validation_curve(
                          GradientBoostingRegressor(),
                          X = X_train, y = y_train,
                          param_name = 'n_estimators',
                          param_range = param_range, cv = 3,
                          scoring="neg_mean_squared_error", n_jobs=-1)

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the validation curve
plt.figure(figsize=(10, 6))

plt.semilogx(param_range, 
             train_scores_mean, 
             label="Training score", 
             color="darkorange")
plt.semilogx(param_range, 
             test_scores_mean, 
             label="Cross-validation score", 
             color="navy")

plt.fill_between(param_range, 
                 train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, 
                 alpha=0.2, 
                 color="darkorange")
plt.fill_between(param_range, 
                 test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, 
                 alpha=0.2, 
                 color="navy")

plt.xlabel("n_estimators")
plt.ylabel("Negative Mean Squared Error")
plt.title("Validation Curve with Gradient Boosting Regressor")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### max_depth

# %%
param_range = list(range(1, 32, 1))

train_scores, test_scores = validation_curve(
                          GradientBoostingRegressor(),
                          X = X_train, y = y_train,
                          param_name = 'max_depth',
                          param_range = param_range, cv = 3,
                          scoring="neg_mean_squared_error", n_jobs=-1)

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the validation curve
plt.figure(figsize=(10, 6))

plt.semilogx(param_range, 
             train_scores_mean, 
             label="Training score", 
             color="darkorange")
plt.semilogx(param_range, 
             test_scores_mean, 
             label="Cross-validation score", 
             color="navy")

plt.fill_between(param_range, 
                 train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, 
                 alpha=0.2, 
                 color="darkorange")
plt.fill_between(param_range, 
                 test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, 
                 alpha=0.2, 
                 color="navy")

plt.xlabel("max_depth")
plt.ylabel("Negative Mean Squared Error")
plt.title("Validation Curve with Gradient Boosting Regressor")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### min_samples_split

# %%
param_range = np.linspace(0.1, 1.0, 10, endpoint=True)

train_scores, test_scores = validation_curve(
                          GradientBoostingRegressor(),
                          X = X_train, y = y_train,
                          param_name = 'min_samples_split',
                          param_range = param_range, cv = 3,
                          scoring="neg_mean_squared_error", n_jobs=-1)

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the validation curve
plt.figure(figsize=(10, 6))

plt.semilogx(param_range, 
             train_scores_mean, 
             label="Training score", 
             color="darkorange")
plt.semilogx(param_range, 
             test_scores_mean, 
             label="Cross-validation score", 
             color="navy")

plt.fill_between(param_range, 
                 train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, 
                 alpha=0.2, 
                 color="darkorange")
plt.fill_between(param_range, 
                 test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, 
                 alpha=0.2, 
                 color="navy")

plt.xlabel("min_sample_split")
plt.ylabel("Negative Mean Squared Error")
plt.title("Validation Curve with Gradient Boosting Regressor")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### min_samples_leaf

# %%
param_range = np.linspace(0.1, 0.5, 5, endpoint=True)

train_scores, test_scores = validation_curve(
                          GradientBoostingRegressor(),
                          X = X_train, y = y_train,
                          param_name = 'min_samples_leaf',
                          param_range = param_range, cv = 3,
                          scoring="neg_mean_squared_error", n_jobs=-1)

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the validation curve
plt.figure(figsize=(10, 6))

plt.semilogx(param_range, 
             train_scores_mean, 
             label="Training score", 
             color="darkorange")
plt.semilogx(param_range, 
             test_scores_mean, 
             label="Cross-validation score", 
             color="navy")

plt.fill_between(param_range, 
                 train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, 
                 alpha=0.2, 
                 color="darkorange")
plt.fill_between(param_range, 
                 test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, 
                 alpha=0.2, 
                 color="navy")

plt.xlabel("min_sample_leaf")
plt.ylabel("Negative Mean Squared Error")
plt.title("Validation Curve with Gradient Boosting Regressor")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## RandomizedSearchCV

# %%
param_distributions = {
    'n_estimators': list(range(20, 50, 1)),
    'max_depth': [1, 2],
    'min_samples_split': [0.7],
    'min_samples_leaf': np.linspace(0.1, 0.2)
}

random_search = RandomizedSearchCV(
    estimator=GradientBoostingRegressor(),
    param_distributions=param_distributions,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    random_state=42,
    verbose=10
)

random_search.fit(X_train, y_train)

print(f"Best parameters: {random_search.best_params_}")
print(f"Best cross-validation score: {random_search.best_score_}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5; 1/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21
# [CV 1/5; 1/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21;, score=-81278885750377888.000 total time=   0.0s
# [CV 2/5; 1/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21
# [CV 2/5; 1/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21;, score=-49080802629914216.000 total time=   0.0s
# [CV 3/5; 1/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21
# [CV 3/5; 1/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21;, score=-101723223621894144.000 total time=   0.0s
# [CV 4/5; 1/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21
# [CV 4/5; 1/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21;, score=-159244502223471136.000 total time=   0.0s
# [CV 5/5; 1/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21
# [CV 5/5; 1/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=21;, score=-82634315759573008.000 total time=   0.0s
# [CV 1/5; 2/50] START max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40
# [CV 1/5; 2/50] END max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40;, score=-75383389837724224.000 total time=   0.0s
# [CV 2/5; 2/50] START max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40
# [CV 2/5; 2/50] END max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40;, score=-53624851623095288.000 total time=   0.0s
# [CV 3/5; 2/50] START max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40
# [CV 3/5; 2/50] END max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40;, score=-101669019205222528.000 total time=   0.0s
# [CV 4/5; 2/50] START max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40
# [CV 4/5; 2/50] END max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40;, score=-155302218233396736.000 total time=   0.0s
# [CV 5/5; 2/50] START max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40
# [CV 5/5; 2/50] END max_depth=1, min_samples_leaf=0.1795918367346939, min_samples_split=0.7, n_estimators=40;, score=-77649173588696480.000 total time=   0.0s
# [CV 1/5; 3/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37
# [CV 1/5; 3/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37;, score=-79463141324768384.000 total time=   0.0s
# [CV 2/5; 3/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37
# [CV 2/5; 3/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37;, score=-56300743202229024.000 total time=   0.0s
# [CV 3/5; 3/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37
# [CV 3/5; 3/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37;, score=-101145189014099936.000 total time=   0.0s
# [CV 4/5; 3/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37
# [CV 4/5; 3/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37;, score=-156709304755729344.000 total time=   0.0s
# [CV 5/5; 3/50] START max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37
# [CV 5/5; 3/50] END max_depth=2, min_samples_leaf=0.12040816326530612, min_samples_split=0.7, n_estimators=37;, score=-78349551315098928.000 total time=   0.0s
# [CV 1/5; 4/50] START max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31
# [CV 1/5; 4/50] END max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31;, score=-79428465658090400.000 total time=   0.0s
# [CV 2/5; 4/50] START max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31
# [CV 2/5; 4/50] END max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31;, score=-51760583294681880.000 total time=   0.0s
# [CV 3/5; 4/50] START max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31
# [CV 3/5; 4/50] END max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31;, score=-100980862547400704.000 total time=   0.0s
# [CV 4/5; 4/50] START max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31
# [CV 4/5; 4/50] END max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31;, score=-157562972804880256.000 total time=   0.0s
# [CV 5/5; 4/50] START max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31
# [CV 5/5; 4/50] END max_depth=1, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=31;, score=-78962433994651856.000 total time=   0.0s
# [CV 1/5; 5/50] START max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 1/5; 5/50] END max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-75699309674601520.000 total time=   0.0s
# [CV 2/5; 5/50] START max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 2/5; 5/50] END max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-54853406644767736.000 total time=   0.0s
# [CV 3/5; 5/50] START max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 3/5; 5/50] END max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-101216961016644192.000 total time=   0.0s
# [CV 4/5; 5/50] START max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 4/5; 5/50] END max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-154967951380962336.000 total time=   0.0s
# [CV 5/5; 5/50] START max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 5/5; 5/50] END max_depth=2, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-78651515777722880.000 total time=   0.0s
# [CV 1/5; 6/50] START max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27
# [CV 1/5; 6/50] END max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27;, score=-77350616430962896.000 total time=   0.0s
# [CV 2/5; 6/50] START max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27
# [CV 2/5; 6/50] END max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27;, score=-50513377370395216.000 total time=   0.0s
# [CV 3/5; 6/50] START max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27
# [CV 3/5; 6/50] END max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27;, score=-100940743809429856.000 total time=   0.0s
# [CV 4/5; 6/50] START max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27
# [CV 4/5; 6/50] END max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27;, score=-156148231327818496.000 total time=   0.0s
# [CV 5/5; 6/50] START max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27
# [CV 5/5; 6/50] END max_depth=1, min_samples_leaf=0.17551020408163265, min_samples_split=0.7, n_estimators=27;, score=-79614878419122288.000 total time=   0.0s
# [CV 1/5; 7/50] START max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21
# [CV 1/5; 7/50] END max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21;, score=-79927188116538320.000 total time=   0.0s
# [CV 2/5; 7/50] START max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21
# [CV 2/5; 7/50] END max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21;, score=-48148384898631840.000 total time=   0.0s
# [CV 3/5; 7/50] START max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21
# [CV 3/5; 7/50] END max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21;, score=-102375650087062064.000 total time=   0.0s
# [CV 4/5; 7/50] START max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21
# [CV 4/5; 7/50] END max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21;, score=-158319115831103264.000 total time=   0.0s
# [CV 5/5; 7/50] START max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21
# [CV 5/5; 7/50] END max_depth=1, min_samples_leaf=0.1959183673469388, min_samples_split=0.7, n_estimators=21;, score=-82672484731847280.000 total time=   0.0s
# [CV 1/5; 8/50] START max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33
# [CV 1/5; 8/50] END max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33;, score=-78623348383652368.000 total time=   0.0s
# [CV 2/5; 8/50] START max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33
# [CV 2/5; 8/50] END max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33;, score=-54334674459284960.000 total time=   0.0s
# [CV 3/5; 8/50] START max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33
# [CV 3/5; 8/50] END max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33;, score=-101134129595876320.000 total time=   0.0s
# [CV 4/5; 8/50] START max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33
# [CV 4/5; 8/50] END max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33;, score=-156975362662413088.000 total time=   0.0s
# [CV 5/5; 8/50] START max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33
# [CV 5/5; 8/50] END max_depth=2, min_samples_leaf=0.14081632653061227, min_samples_split=0.7, n_estimators=33;, score=-78470057698348976.000 total time=   0.0s
# [CV 1/5; 9/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38
# [CV 1/5; 9/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38;, score=-78432075847801088.000 total time=   0.0s
# [CV 2/5; 9/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38
# [CV 2/5; 9/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38;, score=-53200360041339848.000 total time=   0.0s
# [CV 3/5; 9/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38
# [CV 3/5; 9/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38;, score=-101679340036801600.000 total time=   0.0s
# [CV 4/5; 9/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38
# [CV 4/5; 9/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38;, score=-157774508458915840.000 total time=   0.0s
# [CV 5/5; 9/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38
# [CV 5/5; 9/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=38;, score=-79321580829305424.000 total time=   0.0s
# [CV 1/5; 10/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49
# [CV 1/5; 10/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49;, score=-76348533640122608.000 total time=   0.0s
# [CV 2/5; 10/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49
# [CV 2/5; 10/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49;, score=-57744294239205344.000 total time=   0.0s
# [CV 3/5; 10/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49
# [CV 3/5; 10/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49;, score=-102775303773862912.000 total time=   0.0s
# [CV 4/5; 10/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49
# [CV 4/5; 10/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49;, score=-154534921159581152.000 total time=   0.0s
# [CV 5/5; 10/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49
# [CV 5/5; 10/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=49;, score=-77183331438373632.000 total time=   0.0s
# [CV 1/5; 11/50] START max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24
# [CV 1/5; 11/50] END max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24;, score=-80569513277424032.000 total time=   0.0s
# [CV 2/5; 11/50] START max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24
# [CV 2/5; 11/50] END max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24;, score=-50545601662060048.000 total time=   0.0s
# [CV 3/5; 11/50] START max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24
# [CV 3/5; 11/50] END max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24;, score=-101030624252017680.000 total time=   0.0s
# [CV 4/5; 11/50] START max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24
# [CV 4/5; 11/50] END max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24;, score=-156793303062046368.000 total time=   0.0s
# [CV 5/5; 11/50] START max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24
# [CV 5/5; 11/50] END max_depth=2, min_samples_leaf=0.1510204081632653, min_samples_split=0.7, n_estimators=24;, score=-80562515637913104.000 total time=   0.0s
# [CV 1/5; 12/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42
# [CV 1/5; 12/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42;, score=-78879568017499712.000 total time=   0.0s
# [CV 2/5; 12/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42
# [CV 2/5; 12/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42;, score=-53870674964407032.000 total time=   0.0s
# [CV 3/5; 12/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42
# [CV 3/5; 12/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42;, score=-101138346171216624.000 total time=   0.0s
# [CV 4/5; 12/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42
# [CV 4/5; 12/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42;, score=-157460514420390912.000 total time=   0.0s
# [CV 5/5; 12/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42
# [CV 5/5; 12/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=42;, score=-78021231575027488.000 total time=   0.0s
# [CV 1/5; 13/50] START max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34
# [CV 1/5; 13/50] END max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34;, score=-78765597331083088.000 total time=   0.0s
# [CV 2/5; 13/50] START max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34
# [CV 2/5; 13/50] END max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34;, score=-52632756573968680.000 total time=   0.0s
# [CV 3/5; 13/50] START max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34
# [CV 3/5; 13/50] END max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34;, score=-101651000346050704.000 total time=   0.0s
# [CV 4/5; 13/50] START max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34
# [CV 4/5; 13/50] END max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34;, score=-157524837579852320.000 total time=   0.0s
# [CV 5/5; 13/50] START max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34
# [CV 5/5; 13/50] END max_depth=1, min_samples_leaf=0.14285714285714285, min_samples_split=0.7, n_estimators=34;, score=-78717123909249552.000 total time=   0.0s
# [CV 1/5; 14/50] START max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43
# [CV 1/5; 14/50] END max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43;, score=-79541835736381136.000 total time=   0.0s
# [CV 2/5; 14/50] START max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43
# [CV 2/5; 14/50] END max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43;, score=-56627898031589712.000 total time=   0.0s
# [CV 3/5; 14/50] START max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43
# [CV 3/5; 14/50] END max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43;, score=-101689989106198864.000 total time=   0.0s
# [CV 4/5; 14/50] START max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43
# [CV 4/5; 14/50] END max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43;, score=-156467536253817280.000 total time=   0.0s
# [CV 5/5; 14/50] START max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43
# [CV 5/5; 14/50] END max_depth=2, min_samples_leaf=0.1163265306122449, min_samples_split=0.7, n_estimators=43;, score=-78940495738853024.000 total time=   0.0s
# [CV 1/5; 15/50] START max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36
# [CV 1/5; 15/50] END max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36;, score=-75568016052704576.000 total time=   0.0s
# [CV 2/5; 15/50] START max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36
# [CV 2/5; 15/50] END max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36;, score=-54417514766350672.000 total time=   0.0s
# [CV 3/5; 15/50] START max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36
# [CV 3/5; 15/50] END max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36;, score=-101490239134157568.000 total time=   0.0s
# [CV 4/5; 15/50] START max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36
# [CV 4/5; 15/50] END max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36;, score=-154577147184492992.000 total time=   0.0s
# [CV 5/5; 15/50] START max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36
# [CV 5/5; 15/50] END max_depth=2, min_samples_leaf=0.18571428571428572, min_samples_split=0.7, n_estimators=36;, score=-76105483616125952.000 total time=   0.0s
# [CV 1/5; 16/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20
# [CV 1/5; 16/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20;, score=-80700646802220576.000 total time=   0.0s
# [CV 2/5; 16/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20
# [CV 2/5; 16/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20;, score=-47606173978352832.000 total time=   0.0s
# [CV 3/5; 16/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20
# [CV 3/5; 16/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20;, score=-102058846282828912.000 total time=   0.0s
# [CV 4/5; 16/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20
# [CV 4/5; 16/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20;, score=-158848705793055968.000 total time=   0.0s
# [CV 5/5; 16/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20
# [CV 5/5; 16/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=20;, score=-84066901354033136.000 total time=   0.0s
# [CV 1/5; 17/50] START max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43
# [CV 1/5; 17/50] END max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43;, score=-75658739666503040.000 total time=   0.0s
# [CV 2/5; 17/50] START max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43
# [CV 2/5; 17/50] END max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43;, score=-54565318809770008.000 total time=   0.0s
# [CV 3/5; 17/50] START max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43
# [CV 3/5; 17/50] END max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43;, score=-102298394118054912.000 total time=   0.0s
# [CV 4/5; 17/50] START max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43
# [CV 4/5; 17/50] END max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43;, score=-155204003851759040.000 total time=   0.0s
# [CV 5/5; 17/50] START max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43
# [CV 5/5; 17/50] END max_depth=1, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=43;, score=-78662224312764000.000 total time=   0.0s
# [CV 1/5; 18/50] START max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42
# [CV 1/5; 18/50] END max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42;, score=-78568077952515456.000 total time=   0.0s
# [CV 2/5; 18/50] START max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42
# [CV 2/5; 18/50] END max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42;, score=-54165432061758456.000 total time=   0.0s
# [CV 3/5; 18/50] START max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42
# [CV 3/5; 18/50] END max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42;, score=-101138346171216608.000 total time=   0.0s
# [CV 4/5; 18/50] START max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42
# [CV 4/5; 18/50] END max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42;, score=-157460514420390880.000 total time=   0.0s
# [CV 5/5; 18/50] START max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42
# [CV 5/5; 18/50] END max_depth=1, min_samples_leaf=0.1306122448979592, min_samples_split=0.7, n_estimators=42;, score=-78021231575027488.000 total time=   0.0s
# [CV 1/5; 19/50] START max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28
# [CV 1/5; 19/50] END max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28;, score=-76736686150305808.000 total time=   0.0s
# [CV 2/5; 19/50] START max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28
# [CV 2/5; 19/50] END max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28;, score=-52051352836435800.000 total time=   0.0s
# [CV 3/5; 19/50] START max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28
# [CV 3/5; 19/50] END max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28;, score=-100788619949956128.000 total time=   0.0s
# [CV 4/5; 19/50] START max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28
# [CV 4/5; 19/50] END max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28;, score=-155390558789592640.000 total time=   0.0s
# [CV 5/5; 19/50] START max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28
# [CV 5/5; 19/50] END max_depth=2, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=28;, score=-78801115502229792.000 total time=   0.0s
# [CV 1/5; 20/50] START max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46
# [CV 1/5; 20/50] END max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46;, score=-75997718191277216.000 total time=   0.0s
# [CV 2/5; 20/50] START max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46
# [CV 2/5; 20/50] END max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46;, score=-57823549905964296.000 total time=   0.0s
# [CV 3/5; 20/50] START max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46
# [CV 3/5; 20/50] END max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46;, score=-102477015273662752.000 total time=   0.0s
# [CV 4/5; 20/50] START max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46
# [CV 4/5; 20/50] END max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46;, score=-154354213865868832.000 total time=   0.0s
# [CV 5/5; 20/50] START max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46
# [CV 5/5; 20/50] END max_depth=2, min_samples_leaf=0.16938775510204082, min_samples_split=0.7, n_estimators=46;, score=-78006980482367776.000 total time=   0.0s
# [CV 1/5; 21/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34
# [CV 1/5; 21/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34;, score=-79454621662489776.000 total time=   0.0s
# [CV 2/5; 21/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34
# [CV 2/5; 21/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34;, score=-52276403278094184.000 total time=   0.0s
# [CV 3/5; 21/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34
# [CV 3/5; 21/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34;, score=-101651000346050720.000 total time=   0.0s
# [CV 4/5; 21/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34
# [CV 4/5; 21/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34;, score=-157524837579852320.000 total time=   0.0s
# [CV 5/5; 21/50] START max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34
# [CV 5/5; 21/50] END max_depth=1, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=34;, score=-78717123909249552.000 total time=   0.0s
# [CV 1/5; 22/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39
# [CV 1/5; 22/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39;, score=-78505645021149664.000 total time=   0.0s
# [CV 2/5; 22/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39
# [CV 2/5; 22/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39;, score=-53341447631686424.000 total time=   0.0s
# [CV 3/5; 22/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39
# [CV 3/5; 22/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39;, score=-101373392296732192.000 total time=   0.0s
# [CV 4/5; 22/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39
# [CV 4/5; 22/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39;, score=-157546160612774880.000 total time=   0.0s
# [CV 5/5; 22/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39
# [CV 5/5; 22/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=39;, score=-78681583053572272.000 total time=   0.0s
# [CV 1/5; 23/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32
# [CV 1/5; 23/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32;, score=-76052694814420960.000 total time=   0.0s
# [CV 2/5; 23/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32
# [CV 2/5; 23/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32;, score=-52176865313289056.000 total time=   0.0s
# [CV 3/5; 23/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32
# [CV 3/5; 23/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32;, score=-100966552630934480.000 total time=   0.0s
# [CV 4/5; 23/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32
# [CV 4/5; 23/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32;, score=-156194548177354464.000 total time=   0.0s
# [CV 5/5; 23/50] START max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32
# [CV 5/5; 23/50] END max_depth=1, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=32;, score=-78744178155239440.000 total time=   0.0s
# [CV 1/5; 24/50] START max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33
# [CV 1/5; 24/50] END max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33;, score=-78623348383652368.000 total time=   0.0s
# [CV 2/5; 24/50] START max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33
# [CV 2/5; 24/50] END max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33;, score=-54334674459284968.000 total time=   0.0s
# [CV 3/5; 24/50] START max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33
# [CV 3/5; 24/50] END max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33;, score=-101134129595876320.000 total time=   0.0s
# [CV 4/5; 24/50] START max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33
# [CV 4/5; 24/50] END max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33;, score=-156975362662413088.000 total time=   0.0s
# [CV 5/5; 24/50] START max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33
# [CV 5/5; 24/50] END max_depth=2, min_samples_leaf=0.13877551020408163, min_samples_split=0.7, n_estimators=33;, score=-78470057698348976.000 total time=   0.0s
# [CV 1/5; 25/50] START max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30
# [CV 1/5; 25/50] END max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30;, score=-76702592216462224.000 total time=   0.0s
# [CV 2/5; 25/50] START max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30
# [CV 2/5; 25/50] END max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30;, score=-51700046101526048.000 total time=   0.0s
# [CV 3/5; 25/50] START max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30
# [CV 3/5; 25/50] END max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30;, score=-100604134256125776.000 total time=   0.0s
# [CV 4/5; 25/50] START max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30
# [CV 4/5; 25/50] END max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30;, score=-155842648758314912.000 total time=   0.0s
# [CV 5/5; 25/50] START max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30
# [CV 5/5; 25/50] END max_depth=1, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=30;, score=-78296647255882656.000 total time=   0.0s
# [CV 1/5; 26/50] START max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35
# [CV 1/5; 26/50] END max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35;, score=-76336105767687072.000 total time=   0.0s
# [CV 2/5; 26/50] START max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35
# [CV 2/5; 26/50] END max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35;, score=-54096233119206696.000 total time=   0.0s
# [CV 3/5; 26/50] START max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35
# [CV 3/5; 26/50] END max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35;, score=-101216961016644192.000 total time=   0.0s
# [CV 4/5; 26/50] START max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35
# [CV 4/5; 26/50] END max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35;, score=-154514255953838944.000 total time=   0.0s
# [CV 5/5; 26/50] START max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35
# [CV 5/5; 26/50] END max_depth=2, min_samples_leaf=0.19387755102040818, min_samples_split=0.7, n_estimators=35;, score=-76089673636341152.000 total time=   0.0s
# [CV 1/5; 27/50] START max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43
# [CV 1/5; 27/50] END max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43;, score=-75992543374145728.000 total time=   0.0s
# [CV 2/5; 27/50] START max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43
# [CV 2/5; 27/50] END max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43;, score=-55361557311152656.000 total time=   0.0s
# [CV 3/5; 27/50] START max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43
# [CV 3/5; 27/50] END max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43;, score=-102274890141218720.000 total time=   0.0s
# [CV 4/5; 27/50] START max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43
# [CV 4/5; 27/50] END max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43;, score=-154515683877672512.000 total time=   0.0s
# [CV 5/5; 27/50] START max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43
# [CV 5/5; 27/50] END max_depth=2, min_samples_leaf=0.17346938775510207, min_samples_split=0.7, n_estimators=43;, score=-78109898060502528.000 total time=   0.0s
# [CV 1/5; 28/50] START max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46
# [CV 1/5; 28/50] END max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46;, score=-75254263703387664.000 total time=   0.0s
# [CV 2/5; 28/50] START max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46
# [CV 2/5; 28/50] END max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46;, score=-54152593989442864.000 total time=   0.0s
# [CV 3/5; 28/50] START max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46
# [CV 3/5; 28/50] END max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46;, score=-101937844105899120.000 total time=   0.0s
# [CV 4/5; 28/50] START max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46
# [CV 4/5; 28/50] END max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46;, score=-155095046127821792.000 total time=   0.0s
# [CV 5/5; 28/50] START max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46
# [CV 5/5; 28/50] END max_depth=1, min_samples_leaf=0.1816326530612245, min_samples_split=0.7, n_estimators=46;, score=-77501218466763216.000 total time=   0.0s
# [CV 1/5; 29/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46
# [CV 1/5; 29/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46;, score=-78484217843430080.000 total time=   0.0s
# [CV 2/5; 29/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46
# [CV 2/5; 29/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46;, score=-54569618638033552.000 total time=   0.0s
# [CV 3/5; 29/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46
# [CV 3/5; 29/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46;, score=-101665557190081984.000 total time=   0.0s
# [CV 4/5; 29/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46
# [CV 4/5; 29/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46;, score=-157253274650017472.000 total time=   0.0s
# [CV 5/5; 29/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46
# [CV 5/5; 29/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=46;, score=-78697304590723728.000 total time=   0.0s
# [CV 1/5; 30/50] START max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31
# [CV 1/5; 30/50] END max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31;, score=-76267780481482176.000 total time=   0.0s
# [CV 2/5; 30/50] START max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31
# [CV 2/5; 30/50] END max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31;, score=-52041090749126496.000 total time=   0.0s
# [CV 3/5; 30/50] START max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31
# [CV 3/5; 30/50] END max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31;, score=-100980862547400704.000 total time=   0.0s
# [CV 4/5; 30/50] START max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31
# [CV 4/5; 30/50] END max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31;, score=-156063991684803392.000 total time=   0.0s
# [CV 5/5; 30/50] START max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31
# [CV 5/5; 30/50] END max_depth=1, min_samples_leaf=0.1836734693877551, min_samples_split=0.7, n_estimators=31;, score=-78095990024048768.000 total time=   0.0s
# [CV 1/5; 31/50] START max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 1/5; 31/50] END max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-75543243188787616.000 total time=   0.0s
# [CV 2/5; 31/50] START max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 2/5; 31/50] END max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-53047831669841024.000 total time=   0.0s
# [CV 3/5; 31/50] START max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 3/5; 31/50] END max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-101464590629651040.000 total time=   0.0s
# [CV 4/5; 31/50] START max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 4/5; 31/50] END max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-155579272322707200.000 total time=   0.0s
# [CV 5/5; 31/50] START max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35
# [CV 5/5; 31/50] END max_depth=1, min_samples_leaf=0.1673469387755102, min_samples_split=0.7, n_estimators=35;, score=-78709377548796432.000 total time=   0.0s
# [CV 1/5; 32/50] START max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35
# [CV 1/5; 32/50] END max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35;, score=-79135569069225168.000 total time=   0.0s
# [CV 2/5; 32/50] START max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35
# [CV 2/5; 32/50] END max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35;, score=-56202497497950864.000 total time=   0.0s
# [CV 3/5; 32/50] START max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35
# [CV 3/5; 32/50] END max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35;, score=-101158526125236256.000 total time=   0.0s
# [CV 4/5; 32/50] START max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35
# [CV 4/5; 32/50] END max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35;, score=-156627037803174752.000 total time=   0.0s
# [CV 5/5; 32/50] START max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35
# [CV 5/5; 32/50] END max_depth=2, min_samples_leaf=0.11020408163265306, min_samples_split=0.7, n_estimators=35;, score=-79335174321797408.000 total time=   0.0s
# [CV 1/5; 33/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46
# [CV 1/5; 33/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46;, score=-78484217843430080.000 total time=   0.0s
# [CV 2/5; 33/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46
# [CV 2/5; 33/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46;, score=-54335392167826872.000 total time=   0.0s
# [CV 3/5; 33/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46
# [CV 3/5; 33/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46;, score=-101960278354733216.000 total time=   0.0s
# [CV 4/5; 33/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46
# [CV 4/5; 33/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46;, score=-157253274650017472.000 total time=   0.0s
# [CV 5/5; 33/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46
# [CV 5/5; 33/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=46;, score=-78697304590723728.000 total time=   0.0s
# [CV 1/5; 34/50] START max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21
# [CV 1/5; 34/50] END max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21;, score=-78803597672767248.000 total time=   0.0s
# [CV 2/5; 34/50] START max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21
# [CV 2/5; 34/50] END max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21;, score=-49080802629914216.000 total time=   0.0s
# [CV 3/5; 34/50] START max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21
# [CV 3/5; 34/50] END max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21;, score=-101723223621894144.000 total time=   0.0s
# [CV 4/5; 34/50] START max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21
# [CV 4/5; 34/50] END max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21;, score=-157504091616345376.000 total time=   0.0s
# [CV 5/5; 34/50] START max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21
# [CV 5/5; 34/50] END max_depth=2, min_samples_leaf=0.19183673469387758, min_samples_split=0.7, n_estimators=21;, score=-81838354878031792.000 total time=   0.0s
# [CV 1/5; 35/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41
# [CV 1/5; 35/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41;, score=-78720598076940912.000 total time=   0.0s
# [CV 2/5; 35/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41
# [CV 2/5; 35/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41;, score=-53724768317090912.000 total time=   0.0s
# [CV 3/5; 35/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41
# [CV 3/5; 35/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41;, score=-101256216008169040.000 total time=   0.0s
# [CV 4/5; 35/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41
# [CV 4/5; 35/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41;, score=-157277850456550560.000 total time=   0.0s
# [CV 5/5; 35/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41
# [CV 5/5; 35/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=41;, score=-78617478638120544.000 total time=   0.0s
# [CV 1/5; 36/50] START max_depth=1, min_samples_leaf=0.15306122448979592, min_samples_split=0.7, n_estimators=21
# [CV 1/5; 36/50] END max_depth=1, min_samples_leaf=0.15306122448979592, min_samples_split=0.7, n_estimators=21;, score=-81898172624836320.000 total time=   0.0s
# [CV 2/5; 36/50] START max_depth=1, min_samples_leaf=0.15306122448979592, min_samples_split=0.7, n_estimators=21
# ...
# [CV 2/5; 39/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48;, score=-54543525975591760.000 total time=   0.0s
# [CV 3/5; 39/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48
# [CV 3/5; 39/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48;, score=-101420129848588032.000 total time=   0.0s
# [CV 4/5; 39/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48
# [CV 4/5; 39/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48;, score=-157261726647880800.000 total time=   0.0s
# [CV 5/5; 39/50] START max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48
# [CV 5/5; 39/50] END max_depth=1, min_samples_leaf=0.11836734693877551, min_samples_split=0.7, n_estimators=48;, score=-77995913030578160.000 total time=   0.0s
# [CV 1/5; 40/50] START max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28
# [CV 1/5; 40/50] END max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28;, score=-77021929422396784.000 total time=   0.0s
# [CV 2/5; 40/50] START max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28
# [CV 2/5; 40/50] END max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28;, score=-50847121217413984.000 total time=   0.0s
# [CV 3/5; 40/50] START max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28
# [CV 3/5; 40/50] END max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28;, score=-101287245839175296.000 total time=   0.0s
# [CV 4/5; 40/50] START max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28
# [CV 4/5; 40/50] END max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28;, score=-156369491948051744.000 total time=   0.0s
# [CV 5/5; 40/50] START max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28
# [CV 5/5; 40/50] END max_depth=1, min_samples_leaf=0.18775510204081636, min_samples_split=0.7, n_estimators=28;, score=-78787824678852688.000 total time=   0.0s
# [CV 1/5; 41/50] START max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34
# [CV 1/5; 41/50] END max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34;, score=-78765597331083072.000 total time=   0.0s
# [CV 2/5; 41/50] START max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34
# [CV 2/5; 41/50] END max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34;, score=-52276403278094176.000 total time=   0.0s
# [CV 3/5; 41/50] START max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34
# [CV 3/5; 41/50] END max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34;, score=-101651000346050720.000 total time=   0.0s
# [CV 4/5; 41/50] START max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34
# [CV 4/5; 41/50] END max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34;, score=-157524837579852320.000 total time=   0.0s
# [CV 5/5; 41/50] START max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34
# [CV 5/5; 41/50] END max_depth=1, min_samples_leaf=0.11224489795918369, min_samples_split=0.7, n_estimators=34;, score=-78717123909249552.000 total time=   0.0s
# [CV 1/5; 42/50] START max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23
# [CV 1/5; 42/50] END max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23;, score=-81028501525733504.000 total time=   0.0s
# [CV 2/5; 42/50] START max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23
# [CV 2/5; 42/50] END max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23;, score=-48858346816147800.000 total time=   0.0s
# [CV 3/5; 42/50] START max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23
# [CV 3/5; 42/50] END max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23;, score=-101669027645172560.000 total time=   0.0s
# [CV 4/5; 42/50] START max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23
# [CV 4/5; 42/50] END max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23;, score=-158885618544670624.000 total time=   0.0s
# [CV 5/5; 42/50] START max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23
# [CV 5/5; 42/50] END max_depth=1, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=23;, score=-81721596760876976.000 total time=   0.0s
# [CV 1/5; 43/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23
# [CV 1/5; 43/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23;, score=-81028501525733488.000 total time=   0.0s
# [CV 2/5; 43/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23
# [CV 2/5; 43/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23;, score=-48858346816147792.000 total time=   0.0s
# [CV 3/5; 43/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23
# [CV 3/5; 43/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23;, score=-101669027645172560.000 total time=   0.0s
# [CV 4/5; 43/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23
# [CV 4/5; 43/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23;, score=-158885618544670624.000 total time=   0.0s
# [CV 5/5; 43/50] START max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23
# [CV 5/5; 43/50] END max_depth=1, min_samples_leaf=0.12653061224489798, min_samples_split=0.7, n_estimators=23;, score=-81721596760876976.000 total time=   0.0s
# [CV 1/5; 44/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27
# [CV 1/5; 44/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27;, score=-80558888887549664.000 total time=   0.0s
# [CV 2/5; 44/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27
# [CV 2/5; 44/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27;, score=-50513377370395216.000 total time=   0.0s
# [CV 3/5; 44/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27
# [CV 3/5; 44/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27;, score=-100940743809429856.000 total time=   0.0s
# [CV 4/5; 44/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27
# [CV 4/5; 44/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27;, score=-158233312768929216.000 total time=   0.0s
# [CV 5/5; 44/50] START max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27
# [CV 5/5; 44/50] END max_depth=1, min_samples_leaf=0.1489795918367347, min_samples_split=0.7, n_estimators=27;, score=-79614878419122304.000 total time=   0.0s
# [CV 1/5; 45/50] START max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43
# [CV 1/5; 45/50] END max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43;, score=-80448335878412512.000 total time=   0.0s
# [CV 2/5; 45/50] START max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43
# [CV 2/5; 45/50] END max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43;, score=-56815386127626728.000 total time=   0.0s
# [CV 3/5; 45/50] START max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43
# [CV 3/5; 45/50] END max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43;, score=-101689989106198864.000 total time=   0.0s
# [CV 4/5; 45/50] START max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43
# [CV 4/5; 45/50] END max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43;, score=-156809570066348672.000 total time=   0.0s
# [CV 5/5; 45/50] START max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43
# [CV 5/5; 45/50] END max_depth=2, min_samples_leaf=0.10408163265306122, min_samples_split=0.7, n_estimators=43;, score=-79012685914327264.000 total time=   0.0s
# [CV 1/5; 46/50] START max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37
# [CV 1/5; 46/50] END max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37;, score=-79663832494870368.000 total time=   0.0s
# [CV 2/5; 46/50] START max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37
# [CV 2/5; 46/50] END max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37;, score=-56326864586783112.000 total time=   0.0s
# [CV 3/5; 46/50] START max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37
# [CV 3/5; 46/50] END max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37;, score=-101145189014099952.000 total time=   0.0s
# [CV 4/5; 46/50] START max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37
# [CV 4/5; 46/50] END max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37;, score=-157148055300638560.000 total time=   0.0s
# [CV 5/5; 46/50] START max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37
# [CV 5/5; 46/50] END max_depth=2, min_samples_leaf=0.10204081632653061, min_samples_split=0.7, n_estimators=37;, score=-79466147892496128.000 total time=   0.0s
# [CV 1/5; 47/50] START max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45
# [CV 1/5; 47/50] END max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45;, score=-75393856977262288.000 total time=   0.0s
# [CV 2/5; 47/50] START max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45
# [CV 2/5; 47/50] END max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45;, score=-56539600977015400.000 total time=   0.0s
# [CV 3/5; 47/50] START max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45
# [CV 3/5; 47/50] END max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45;, score=-102099392686731072.000 total time=   0.0s
# [CV 4/5; 47/50] START max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45
# [CV 4/5; 47/50] END max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45;, score=-156252922736819616.000 total time=   0.0s
# [CV 5/5; 47/50] START max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45
# [CV 5/5; 47/50] END max_depth=2, min_samples_leaf=0.16122448979591839, min_samples_split=0.7, n_estimators=45;, score=-78807789526949232.000 total time=   0.0s
# [CV 1/5; 48/50] START max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34
# [CV 1/5; 48/50] END max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34;, score=-79342451479362192.000 total time=   0.0s
# [CV 2/5; 48/50] START max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34
# [CV 2/5; 48/50] END max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34;, score=-52276403278094184.000 total time=   0.0s
# [CV 3/5; 48/50] START max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34
# [CV 3/5; 48/50] END max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34;, score=-100492268959917984.000 total time=   0.0s
# [CV 4/5; 48/50] START max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34
# [CV 4/5; 48/50] END max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34;, score=-157524837579852320.000 total time=   0.0s
# [CV 5/5; 48/50] START max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34
# [CV 5/5; 48/50] END max_depth=1, min_samples_leaf=0.1, min_samples_split=0.7, n_estimators=34;, score=-77384369416259920.000 total time=   0.0s
# [CV 1/5; 49/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37
# [CV 1/5; 49/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37;, score=-75836090791254112.000 total time=   0.0s
# [CV 2/5; 49/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37
# [CV 2/5; 49/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37;, score=-55799604266672928.000 total time=   0.0s
# [CV 3/5; 49/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37
# [CV 3/5; 49/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37;, score=-101660611934257984.000 total time=   0.0s
# [CV 4/5; 49/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37
# [CV 4/5; 49/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37;, score=-154774299667846880.000 total time=   0.0s
# [CV 5/5; 49/50] START max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37
# [CV 5/5; 49/50] END max_depth=2, min_samples_leaf=0.17142857142857143, min_samples_split=0.7, n_estimators=37;, score=-78186968761388464.000 total time=   0.0s
# [CV 1/5; 50/50] START max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30
# [CV 1/5; 50/50] END max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30;, score=-79398423309348480.000 total time=   0.0s
# [CV 2/5; 50/50] START max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30
# [CV 2/5; 50/50] END max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30;, score=-53770795868493680.000 total time=   0.0s
# [CV 3/5; 50/50] START max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30
# [CV 3/5; 50/50] END max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30;, score=-101022416432084864.000 total time=   0.0s
# [CV 4/5; 50/50] START max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30
# [CV 4/5; 50/50] END max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30;, score=-157230205894507904.000 total time=   0.0s
# [CV 5/5; 50/50] START max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30
# [CV 5/5; 50/50] END max_depth=2, min_samples_leaf=0.10612244897959185, min_samples_split=0.7, n_estimators=30;, score=-79367684174837504.000 total time=   0.0s
# Best parameters: {'n_estimators': 36, 'min_samples_split': 0.7, 'min_samples_leaf': 0.18571428571428572, 'max_depth': 2}
# Best cross-validation score: -9.243168015076635e+16

# %% [markdown]
# ## Model Developmet

# %%
GBR_new = GradientBoostingRegressor(max_depth=2, 
                                    min_samples_leaf=0.18571428571428572, 
                                    min_samples_split=0.7,
                                    n_estimators=36)

model = GBR_new.fit(X_train, y_train)

# %%
y_pred = GBR_new.predict(X_test)

rmse = root_mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_pred, y_test)
print(f"RMSE:{rmse} and MSE:{mse}")
# Out:
# RMSE:466568372.4586636 and MSE:2.1768604617872624e+17

# %%
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs True Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
plt.show()
