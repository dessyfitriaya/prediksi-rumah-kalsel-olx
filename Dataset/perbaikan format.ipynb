# %%
import pandas as pd

# %%
df = pd.read_csv("rumah_olx.csv")

# %%
#df = df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
#                                           Product Name             Price  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN    Rp 400.000.000
# 1                                  Rumah baru dibangun    Rp 400.000.000
# 2                                   SOLD OUT (TERJUAL)    Rp 550.000.000
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...    Rp 555.000.000
# 4                              RUMAH MINIMALIS type 45    Rp 400.000.000
# ..                                                 ...               ...
# 442                    Dijual cepat Tanah dan Bangunan    Rp 230.000.000
# 443  Rumah mewah murah type 650/1.200m2 samping mus...  Rp 3.000.000.000
# 444                   Dijual Cepat rumah milik pribadi    Rp 950.000.000
# 445                              Di jual rumah type 45    Rp 350.000.000
# 446      Jual Rumah Banjarbaru Loktabat Utara, LT10x19    Rp 400.000.000
#
#                    Detail                              Location
# ...

# %%
df.rename(columns={'Detail': 'kamar_tidur'}, inplace=True)

# %%
df
# Out:
#                                           Product Name             Price  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN    Rp 400.000.000
# 1                                  Rumah baru dibangun    Rp 400.000.000
# 2                                   SOLD OUT (TERJUAL)    Rp 550.000.000
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...    Rp 555.000.000
# 4                              RUMAH MINIMALIS type 45    Rp 400.000.000
# ..                                                 ...               ...
# 443                    Dijual cepat Tanah dan Bangunan    Rp 230.000.000
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  Rp 3.000.000.000
# 445                   Dijual Cepat rumah milik pribadi    Rp 950.000.000
# 446                              Di jual rumah type 45    Rp 350.000.000
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19    Rp 400.000.000
#
#               kamar_tidur                              Location
# ...

# %%
df['kamar_mandi'] = df['kamar_tidur']

# %%
df['luas'] = df['kamar_tidur']

# %%
df['location'] = df['Location']

# %%
df = df.drop(columns=['Location'])

# %%
df
# Out:
#                                           Product Name             Price  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN    Rp 400.000.000
# 1                                  Rumah baru dibangun    Rp 400.000.000
# 2                                   SOLD OUT (TERJUAL)    Rp 550.000.000
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...    Rp 555.000.000
# 4                              RUMAH MINIMALIS type 45    Rp 400.000.000
# ..                                                 ...               ...
# 443                    Dijual cepat Tanah dan Bangunan    Rp 230.000.000
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  Rp 3.000.000.000
# 445                   Dijual Cepat rumah milik pribadi    Rp 950.000.000
# 446                              Di jual rumah type 45    Rp 350.000.000
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19    Rp 400.000.000
#
#               kamar_tidur           kamar_mandi                  luas  \
# ...

# %%
df['Price'] = df['Price'].str.split(' ').str[1]

# %%
df
# Out:
#                                           Product Name          Price  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN    400.000.000
# 1                                  Rumah baru dibangun    400.000.000
# 2                                   SOLD OUT (TERJUAL)    550.000.000
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...    555.000.000
# 4                              RUMAH MINIMALIS type 45    400.000.000
# ..                                                 ...            ...
# 443                    Dijual cepat Tanah dan Bangunan    230.000.000
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  3.000.000.000
# 445                   Dijual Cepat rumah milik pribadi    950.000.000
# 446                              Di jual rumah type 45    350.000.000
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19    400.000.000
#
#               kamar_tidur           kamar_mandi                  luas  \
# ...

# %%
df['price'] = df['Price']

# %%
df
# Out:
#                                           Product Name          Price  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN    400.000.000
# 1                                  Rumah baru dibangun    400.000.000
# 2                                   SOLD OUT (TERJUAL)    550.000.000
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...    555.000.000
# 4                              RUMAH MINIMALIS type 45    400.000.000
# ..                                                 ...            ...
# 443                    Dijual cepat Tanah dan Bangunan    230.000.000
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  3.000.000.000
# 445                   Dijual Cepat rumah milik pribadi    950.000.000
# 446                              Di jual rumah type 45    350.000.000
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19    400.000.000
#
#               kamar_tidur           kamar_mandi                  luas  \
# ...

# %%
df = df.drop(columns=['Price'])

# %%
df
# Out:
#                                           Product Name           kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN   2 KT - 2 KM - 70 m2
# 1                                  Rumah baru dibangun   2 KT - 1 KM - 60 m2
# 2                                   SOLD OUT (TERJUAL)  2 KT - 1 KM - 120 m2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...  3 KT - 2 KM - 100 m2
# 4                              RUMAH MINIMALIS type 45   2 KT - 1 KM - 45 m2
# ..                                                 ...                   ...
# 443                    Dijual cepat Tanah dan Bangunan  2 KT - 1 KM - 182 m2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  5 KT - 5 KM - 650 m2
# 445                   Dijual Cepat rumah milik pribadi  6 KT - 2 KM - 160 m2
# 446                              Di jual rumah type 45   2 KT - 1 KM - 45 m2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19  2 KT - 1 KM - 150 m2
#
# ...

# %%
df['kecamatan'] = df['location']
df['kota'] = df['location']

# %%
df
# Out:
#                                           Product Name           kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN   2 KT - 2 KM - 70 m2
# 1                                  Rumah baru dibangun   2 KT - 1 KM - 60 m2
# 2                                   SOLD OUT (TERJUAL)  2 KT - 1 KM - 120 m2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...  3 KT - 2 KM - 100 m2
# 4                              RUMAH MINIMALIS type 45   2 KT - 1 KM - 45 m2
# ..                                                 ...                   ...
# 443                    Dijual cepat Tanah dan Bangunan  2 KT - 1 KM - 182 m2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...  5 KT - 5 KM - 650 m2
# 445                   Dijual Cepat rumah milik pribadi  6 KT - 2 KM - 160 m2
# 446                              Di jual rumah type 45   2 KT - 1 KM - 45 m2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19  2 KT - 1 KM - 150 m2
#
# ...

# %%
df['kamar_tidur'] = df['kamar_tidur'].str.split(' - ').str[0]
df['kamar_tidur'] = df['kamar_tidur'].str.split(' ').str[0]

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#               kamar_mandi                  luas  \
# 0     2 KT - 2 KM - 70 m2   2 KT - 2 KM - 70 m2
# 1     2 KT - 1 KM - 60 m2   2 KT - 1 KM - 60 m2
# ...

# %%
df['kamar_mandi'] = df['kamar_mandi'].str.split(' - ').str[1]
df['kamar_mandi'] = df['kamar_mandi'].str.split(' ').str[0]

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi                  luas                              location  \
# 0             2   2 KT - 2 KM - 70 m2   Banjarmasin Timur, Banjarmasin Kota
# ...

# %%
df['luas'] = df['luas'].str.split(' - ').str[2]
df['luas'] = df['luas'].str.split(' ').str[0]

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas                              location          price  \
# 0             2   70   Banjarmasin Timur, Banjarmasin Kota    400.000.000
# ...

# %%
df = df.drop(columns=['location'])

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas          price                             kecamatan  \
# 0             2   70    400.000.000   Banjarmasin Timur, Banjarmasin Kota
# ...

# %%
df['kecamatan'] = df['kecamatan'].str.split(', ').str[0]

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas          price            kecamatan  \
# 0             2   70    400.000.000    Banjarmasin Timur
# ...

# %%
df['kota'] = df['kota'].str.split(', ').str[1]

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas          price            kecamatan              kota
# 0             2   70    400.000.000    Banjarmasin Timur  Banjarmasin Kota
# ...

# %%
df['price'] = df['price'].str.replace('.', '')

# %%
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas       price            kecamatan              kota
# 0             2   70   400000000    Banjarmasin Timur  Banjarmasin Kota
# ...

# %%
df['price'] = df['price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  448 non-null    object
#  1   kamar_tidur   448 non-null    object
#  2   kamar_mandi   448 non-null    object
#  3   luas          448 non-null    object
#  4   price         448 non-null    int64
#  5   kecamatan     448 non-null    object
#  6   kota          448 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 24.6+ KB

# %%
def remove(value):
    if '>' in value:
        return value.replace('>', '')
    return value

df['kamar_tidur'] = df['kamar_tidur'].apply(remove)
df
# Out:
#                                           Product Name kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN           2
# 1                                  Rumah baru dibangun           2
# 2                                   SOLD OUT (TERJUAL)           2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...           3
# 4                              RUMAH MINIMALIS type 45           2
# ..                                                 ...         ...
# 443                    Dijual cepat Tanah dan Bangunan           2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...           5
# 445                   Dijual Cepat rumah milik pribadi           6
# 446                              Di jual rumah type 45           2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19           2
#
#     kamar_mandi luas       price            kecamatan              kota
# 0             2   70   400000000    Banjarmasin Timur  Banjarmasin Kota
# ...

# %%
df['kamar_tidur'] = df['kamar_tidur'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  448 non-null    object
#  1   kamar_tidur   448 non-null    int64
#  2   kamar_mandi   448 non-null    object
#  3   luas          448 non-null    object
#  4   price         448 non-null    int64
#  5   kecamatan     448 non-null    object
#  6   kota          448 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 24.6+ KB

# %%
df['kamar_mandi'] = df['kamar_mandi'].astype('int64')

# %%
df['luas'] = df['luas'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  448 non-null    object
#  1   kamar_tidur   448 non-null    int64
#  2   kamar_mandi   448 non-null    int64
#  3   luas          448 non-null    int64
#  4   price         448 non-null    int64
#  5   kecamatan     448 non-null    object
#  6   kota          448 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 24.6+ KB

# %%
df['harga'] = df['price']

# %%
df
# Out:
#                                           Product Name  kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN            2
# 1                                  Rumah baru dibangun            2
# 2                                   SOLD OUT (TERJUAL)            2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...            3
# 4                              RUMAH MINIMALIS type 45            2
# ..                                                 ...          ...
# 443                    Dijual cepat Tanah dan Bangunan            2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...            5
# 445                   Dijual Cepat rumah milik pribadi            6
# 446                              Di jual rumah type 45            2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19            2
#
#      kamar_mandi  luas       price            kecamatan              kota  \
# 0              2    70   400000000    Banjarmasin Timur  Banjarmasin Kota
# ...

# %%
df = df.drop(columns=['price'])

# %%
df
# Out:
#                                           Product Name  kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN            2
# 1                                  Rumah baru dibangun            2
# 2                                   SOLD OUT (TERJUAL)            2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...            3
# 4                              RUMAH MINIMALIS type 45            2
# ..                                                 ...          ...
# 443                    Dijual cepat Tanah dan Bangunan            2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...            5
# 445                   Dijual Cepat rumah milik pribadi            6
# 446                              Di jual rumah type 45            2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19            2
#
#      kamar_mandi  luas            kecamatan              kota       harga
# 0              2    70    Banjarmasin Timur  Banjarmasin Kota   400000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  448 non-null    object
#  1   kamar_tidur   448 non-null    int64
#  2   kamar_mandi   448 non-null    int64
#  3   luas          448 non-null    int64
#  4   kecamatan     448 non-null    object
#  5   kota          448 non-null    object
#  6   harga         448 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 24.6+ KB

# %%
df.rename(columns={'Product Name':'nama_produk'})
# Out:
#                                            nama_produk  kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN            2
# 1                                  Rumah baru dibangun            2
# 2                                   SOLD OUT (TERJUAL)            2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...            3
# 4                              RUMAH MINIMALIS type 45            2
# ..                                                 ...          ...
# 443                    Dijual cepat Tanah dan Bangunan            2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...            5
# 445                   Dijual Cepat rumah milik pribadi            6
# 446                              Di jual rumah type 45            2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19            2
#
#      kamar_mandi  luas            kecamatan              kota       harga
# 0              2    70    Banjarmasin Timur  Banjarmasin Kota   400000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  448 non-null    object
#  1   kamar_tidur   448 non-null    int64
#  2   kamar_mandi   448 non-null    int64
#  3   luas          448 non-null    int64
#  4   kecamatan     448 non-null    object
#  5   kota          448 non-null    object
#  6   harga         448 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 24.6+ KB

# %%
df['kota'] = df['kota'].str.split(' ').str[0]

# %%
df
# Out:
#                                           Product Name  kamar_tidur  \
# 0                RUMAH MINIMALIS STRATEGIS BANJARMASIN            2
# 1                                  Rumah baru dibangun            2
# 2                                   SOLD OUT (TERJUAL)            2
# 3    DI JUAL CEPAT RUMAH PRIBADI MURAH Di BAWAH PAS...            3
# 4                              RUMAH MINIMALIS type 45            2
# ..                                                 ...          ...
# 443                    Dijual cepat Tanah dan Bangunan            2
# 444  Rumah mewah murah type 650/1.200m2 samping mus...            5
# 445                   Dijual Cepat rumah milik pribadi            6
# 446                              Di jual rumah type 45            2
# 447      Jual Rumah Banjarbaru Loktabat Utara, LT10x19            2
#
#      kamar_mandi  luas            kecamatan         kota       harga
# 0              2    70    Banjarmasin Timur  Banjarmasin   400000000
# ...

# %%
#df.to_csv("rumah_olx_new.csv", index=False)

# %%
df.describe()
# Out:
#        kamar_tidur  kamar_mandi         luas         harga
# count   448.000000   448.000000   448.000000  4.480000e+02
# mean      2.729911     1.781250   128.895089  1.035998e+09
# std       1.222752     1.087413   183.439571  5.373240e+09
# min       1.000000     1.000000     0.000000  9.000000e+00
# 25%       2.000000     1.000000    48.000000  2.000000e+08
# 50%       2.000000     2.000000    90.000000  4.000000e+08
# 75%       3.000000     2.000000   150.000000  8.250000e+08
# max      10.000000     9.000000  2020.000000  1.100000e+11

# %%
df[df['luas']==0]
# Out:
#                             Product Name  kamar_tidur  kamar_mandi  luas  \
# 22                Jual Rumah pribadi SHM            4            2     0
# 141             Rumah dan toko strategis            4            2     0
# 289  Disewakan bedakan 600 ribu perbulan            2            1     0
#
#              kecamatan         kota       harga
# 22   Banjarmasin Utara  Banjarmasin   565000000
# 141  Banjarmasin Utara  Banjarmasin  2700000000
# 289  Banjarmasin Timur  Banjarmasin      600000

# %%
df[df['luas']==2020]
# Out:
#                Product Name  kamar_tidur  kamar_mandi  luas  \
# 248  DIJUAL satu buah rumah            1            9  2020
#
#              kecamatan         kota      harga
# 248  Banjarmasin Barat  Banjarmasin  200000000

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df
